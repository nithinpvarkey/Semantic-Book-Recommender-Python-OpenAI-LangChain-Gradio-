# %%
import kagglehub
from matplotlib.pyplot import plot_date

# Download latest version
path = kagglehub.dataset_download("dylanjcastillo/7k-books-with-metadata")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/codespace/.cache/kagglehub/datasets/dylanjcastillo/7k-books-with-metadata/versions/3

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

books = pd.read_csv(f"{path}/books.csv")
books
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
print(books.columns.to_list())
# Out:
# ['isbn13', 'isbn10', 'title', 'subtitle', 'authors', 'categories', 'thumbnail', 'description', 'published_year', 'average_rating', 'num_pages', 'ratings_count']

# %%
books.describe().T
# Out:
#                  count          mean           std           min  \
# isbn13          6810.0  9.780677e+12  6.068911e+08  9.780002e+12
# published_year  6804.0  1.998630e+03  1.048426e+01  1.853000e+03
# average_rating  6767.0  3.933284e+00  3.313516e-01  0.000000e+00
# num_pages       6767.0  3.481810e+02  2.423768e+02  0.000000e+00
# ratings_count   6767.0  2.106910e+04  1.376207e+05  0.000000e+00
#
#                          25%           50%           75%           max
# isbn13          9.780330e+12  9.780553e+12  9.780810e+12  9.789042e+12
# published_year  1.996000e+03  2.002000e+03  2.005000e+03  2.019000e+03
# average_rating  3.770000e+00  3.960000e+00  4.130000e+00  5.000000e+00
# num_pages       2.080000e+02  3.040000e+02  4.200000e+02  3.342000e+03
# ratings_count   1.590000e+02  1.018000e+03  5.992500e+03  5.629932e+06

# %%
cat = books.select_dtypes(include=['object'])
cat.describe().T
# Out:
#             count unique                                                top  \
# isbn10       6810   6810                                         0002005883
# title        6810   6398                              The Lord of the Rings
# subtitle     2381   2009                                            A Novel
# authors      6738   3780                                    Agatha Christie
# categories   6711    567                                            Fiction
# thumbnail    6481   6481  http://books.google.com/books/content?id=KQZCP...
# description  6548   6474                                 No Marketing Blurb
#
#              freq
# isbn10          1
# title          11
# subtitle      226
# authors        37
# categories   2588
# thumbnail       1
# description     6

# %% [markdown]
# ### Visualize the data

# %%
import matplotlib.pyplot as plt
import numpy as np

missing = books.isna().to_numpy().T
fig, ax = plt.subplots()

im = ax.imshow(missing, aspect='auto', cmap='gray', interpolation='none')

ax.set_xlabel("Columns")
ax.set_ylabel("missing values")


ax.set_yticks(np.arange(len(books.columns)))
ax.set_yticklabels(books.columns)

plt.show()

# %%
books.head()
# Out:
#           isbn13      isbn10           title subtitle  \
# 0  9780002005883  0002005883          Gilead      NaN
# 1  9780002261982  0002261987    Spider's Web  A Novel
# 2  9780006163831  0006163831    The One Tree      NaN
# 3  9780006178736  0006178731  Rage of angels      NaN
# 4  9780006280897  0006280897  The Four Loves      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
# 3                   Sidney Sheldon                        Fiction
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
# ...

# %%
books["missing_description"] = np.where(books["description"].isna(), 1,0)
books["age_of_book"] = 2025-books["published_year"]
books.head()
# Out:
#           isbn13      isbn10           title subtitle  \
# 0  9780002005883  0002005883          Gilead      NaN
# 1  9780002261982  0002261987    Spider's Web  A Novel
# 2  9780006163831  0006163831    The One Tree      NaN
# 3  9780006178736  0006178731  Rage of angels      NaN
# 4  9780006280897  0006280897  The Four Loves      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
# 3                   Sidney Sheldon                        Fiction
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
# ...

# %%
columns_of_interest = ["num_pages","age_of_book","missing_description","average_rating"]
correlation_matrix = books[columns_of_interest].corr(method = "spearman")


import seaborn as sns
sns.set_theme(style="white")
plt.figure(figsize=(8, 6))
heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", cbar_kws={"label": "Spearman correlation"})
heatmap.set_title("Correlation heatmap")
plt.show()

# %%
books_update_missing = books[~(books["description"].isna()) &
                             ~(books["num_pages"].isna()) &
                             ~(books["average_rating"].isna()) &
                             ~(books["published_year"].isna())
]

books_update_missing.head()
# Out:
#           isbn13      isbn10           title subtitle  \
# 0  9780002005883  0002005883          Gilead      NaN
# 1  9780002261982  0002261987    Spider's Web  A Novel
# 2  9780006163831  0006163831    The One Tree      NaN
# 3  9780006178736  0006178731  Rage of angels      NaN
# 4  9780006280897  0006280897  The Four Loves      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
# 3                   Sidney Sheldon                        Fiction
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
# ...

# %%
books_update_missing["words_in_description"] = books_update_missing["description"].str.split().str.len()
books_update_missing.head()
# Out:
#           isbn13      isbn10           title subtitle  \
# 0  9780002005883  0002005883          Gilead      NaN
# 1  9780002261982  0002261987    Spider's Web  A Novel
# 2  9780006163831  0006163831    The One Tree      NaN
# 3  9780006178736  0006178731  Rage of angels      NaN
# 4  9780006280897  0006280897  The Four Loves      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 2             Stephen R. Donaldson               American fiction
# 3                   Sidney Sheldon                        Fiction
# 4              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# 2  http://books.google.com/books/content?id=OmQaw...
# ...

# %%
books_update_missing.loc[books_update_missing["words_in_description"].between(1,4), "description"]
# Out:
# 6                                           Donation.
# 11                                     Fantasy-roman.
# 748              Includes bibliographical references.
# 770                             Bound For Oregon (PB)
# 775                                No Marketing Blurb
# 812                                No Marketing Blurb
# 857                          First published in 1813.
# 944                         Edited by Maurice Hindle.
# 953                        DEFOE/ROBINSON CRUSOE (BC)
# 954                             Edited by John Carey.
# 962                         ALLEN/GETTING THINGS DONE
# 1054                            GILBERT/EAT PRAY LOVE
# 1056    "Graham Greene centennial, 1904-2004"--Cover.
# 1060                   STEINBECK/GRAPES OF WRATH (BC)
# 1346                                   Fantasy-roman.
# 1546                                      Winter 2003
# 1610                                      Winter 1999
# ...

# %%
books_update_missing.loc[books_update_missing["words_in_description"].between(5,10), "description"]
# Out:
# 77                         Nonsense rhyming story. 4 yrs+
# 104                        Library of Liberal Arts title.
# 241     Originally published: [New York]: Clarion Book...
# 357     The most eloquent translation of Homer's Odyss...
# 472     A study of the influence Romanticism exerts up...
#                               ...
# 6558    A moving anthology of correspondence between G...
# 6704      Accessible and affordable illustrated biography
# 6726       Presents two complete novels from Henry James.
# 6757                          Audio Book- unabriged on CD
# 6795    Book Of Five Rings is a Kodansha International...
# Name: description, Length: 102, dtype: object

# %%
books_update_missing.loc[books_update_missing["words_in_description"].between(25,40), "description"]
# Out:
# 9       Kate Blackwell is an enigma and one of the mos...
# 14      Available in the U.S. for the first time, this...
# 20      It is 1937, and Charles Ashworth, a Canon to t...
# 21      Reissue of the author's most famous and well-l...
# 39      "The two works 'On fairy-stories' and 'Leaf by...
#                               ...
# 6768    Citing a harrowing lack of adequate shelter an...
# 6775    Presents nearly one thousand recipes--from app...
# 6779    Edited by the creator and executive producer o...
# 6799    This book is the story of a young girl obsesse...
# 6801    Forster's lively, informed originality and wit...
# Name: description, Length: 2055, dtype: object

# %%
books_update_missing_25_words = books_update_missing[books_update_missing["words_in_description"] >= 25]
books_update_missing_25_words.head()
# Out:
#           isbn13      isbn10                title subtitle  \
# 0  9780002005883  0002005883               Gilead      NaN
# 1  9780002261982  0002261987         Spider's Web  A Novel
# 3  9780006178736  0006178731       Rage of angels      NaN
# 4  9780006280897  0006280897       The Four Loves      NaN
# 5  9780006280934  0006280935  The Problem of Pain      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 3                   Sidney Sheldon                        Fiction
# 4              Clive Staples Lewis                 Christian life
# 5              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# ...

# %%
books_update_missing_25_words["title_and_subtitle"] = (
    np.where(books_update_missing_25_words["subtitle"].isna(), books_update_missing_25_words["title"],
             books_update_missing_25_words[["title", "subtitle"]].astype(str).agg(": ".join, axis=1))
)

books_update_missing_25_words.head()
# Out:
#           isbn13      isbn10                title subtitle  \
# 0  9780002005883  0002005883               Gilead      NaN
# 1  9780002261982  0002261987         Spider's Web  A Novel
# 3  9780006178736  0006178731       Rage of angels      NaN
# 4  9780006280897  0006280897       The Four Loves      NaN
# 5  9780006280934  0006280935  The Problem of Pain      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 3                   Sidney Sheldon                        Fiction
# 4              Clive Staples Lewis                 Christian life
# 5              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# ...

# %%
books_update_missing_25_words["tagged_description"] = books_update_missing_25_words[["isbn13", "description"]].astype(str).agg(" ".join, axis=1)

books_update_missing_25_words.head()
# Out:
#           isbn13      isbn10                title subtitle  \
# 0  9780002005883  0002005883               Gilead      NaN
# 1  9780002261982  0002261987         Spider's Web  A Novel
# 3  9780006178736  0006178731       Rage of angels      NaN
# 4  9780006280897  0006280897       The Four Loves      NaN
# 5  9780006280934  0006280935  The Problem of Pain      NaN
#
#                            authors                     categories  \
# 0               Marilynne Robinson                        Fiction
# 1  Charles Osborne;Agatha Christie  Detective and mystery stories
# 3                   Sidney Sheldon                        Fiction
# 4              Clive Staples Lewis                 Christian life
# 5              Clive Staples Lewis                 Christian life
#
#                                            thumbnail  \
# 0  http://books.google.com/books/content?id=KQZCP...
# 1  http://books.google.com/books/content?id=gA5GP...
# ...

# %%
(
    books_update_missing_25_words
    .drop(["subtitle", "missing_description", "age_of_book", "words_in_description"], axis=1)
    .to_csv("books_cleaned.csv", index = False)
)

# %%
df = pd.read_csv("books_cleaned.csv")
df
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# ...

# %%
df.isna().sum()
# Out:
# isbn13                  0
# isbn10                  0
# title                   0
# authors                32
# categories             30
# thumbnail             166
# description             0
# published_year          0
# average_rating          0
# num_pages               0
# ratings_count           0
# title_and_subtitle      0
# tagged_description      0
# dtype: int64
