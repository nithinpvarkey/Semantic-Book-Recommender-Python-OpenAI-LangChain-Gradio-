# %%
import pandas as pd
books = pd.read_csv("books_with_categories.csv")
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# ...

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

classifier = pipeline("text-classification",
                 model="j-hartmann/emotion-english-distilroberta-base",
                 top_k = None)
# Out:
# Device set to use cpu

# %%
classifier("i love this book")
# Out:
# [[{'label': 'joy', 'score': 0.9873034358024597},
#   {'label': 'sadness', 'score': 0.006332178600132465},
#   {'label': 'surprise', 'score': 0.0026092641055583954},
#   {'label': 'anger', 'score': 0.0018761259270831943},
#   {'label': 'neutral', 'score': 0.0008471414912492037},
#   {'label': 'fear', 'score': 0.0006410860223695636},
#   {'label': 'disgust', 'score': 0.0003906972415279597}]]

# %%
books["description"][0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world 
# ...

# %%
classifier(books["description"][0])
# Out:
# [[{'label': 'fear', 'score': 0.654839813709259},
#   {'label': 'neutral', 'score': 0.16985264420509338},
#   {'label': 'sadness', 'score': 0.11640956997871399},
#   {'label': 'surprise', 'score': 0.020700659602880478},
#   {'label': 'disgust', 'score': 0.019100705161690712},
#   {'label': 'joy', 'score': 0.015161501243710518},
#   {'label': 'anger', 'score': 0.003935148939490318}]]

# %%
classifier(books["description"][0].split("."))
# Out:
# [[{'label': 'surprise', 'score': 0.7296021580696106},
#   {'label': 'neutral', 'score': 0.14038586616516113},
#   {'label': 'fear', 'score': 0.06816233694553375},
#   {'label': 'joy', 'score': 0.04794260486960411},
#   {'label': 'anger', 'score': 0.009156367741525173},
#   {'label': 'disgust', 'score': 0.0026284796185791492},
#   {'label': 'sadness', 'score': 0.0021221658680588007}],
#  [{'label': 'neutral', 'score': 0.4493700861930847},
#   {'label': 'disgust', 'score': 0.2735915184020996},
#   {'label': 'joy', 'score': 0.10908326506614685},
#   {'label': 'sadness', 'score': 0.09362751990556717},
#   {'label': 'anger', 'score': 0.04047833010554314},
#   {'label': 'surprise', 'score': 0.026970162987709045},
#   {'label': 'fear', 'score': 0.006879063323140144}],
#  [{'label': 'neutral', 'score': 0.6462157368659973},
#   {'label': 'sadness', 'score': 0.24273350834846497},
#   {'label': 'disgust', 'score': 0.04342273622751236},
#   {'label': 'surprise', 'score': 0.028300566598773003},
# ...

# %%
sentences = books["description"][0].split(".")
predictions = classifier(sentences)

# %%
sentences[0]
# Out:
# 'A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives'

# %%
predictions
# Out:
# [[{'label': 'surprise', 'score': 0.7296021580696106},
#   {'label': 'neutral', 'score': 0.14038586616516113},
#   {'label': 'fear', 'score': 0.06816233694553375},
#   {'label': 'joy', 'score': 0.04794260486960411},
#   {'label': 'anger', 'score': 0.009156367741525173},
#   {'label': 'disgust', 'score': 0.0026284796185791492},
#   {'label': 'sadness', 'score': 0.0021221658680588007}],
#  [{'label': 'neutral', 'score': 0.4493700861930847},
#   {'label': 'disgust', 'score': 0.2735915184020996},
#   {'label': 'joy', 'score': 0.10908326506614685},
#   {'label': 'sadness', 'score': 0.09362751990556717},
#   {'label': 'anger', 'score': 0.04047833010554314},
#   {'label': 'surprise', 'score': 0.026970162987709045},
#   {'label': 'fear', 'score': 0.006879063323140144}],
#  [{'label': 'neutral', 'score': 0.6462157368659973},
#   {'label': 'sadness', 'score': 0.24273350834846497},
#   {'label': 'disgust', 'score': 0.04342273622751236},
#   {'label': 'surprise', 'score': 0.028300566598773003},
# ...

# %%
predictions[0]
# Out:
# [{'label': 'surprise', 'score': 0.7296021580696106},
#  {'label': 'neutral', 'score': 0.14038586616516113},
#  {'label': 'fear', 'score': 0.06816233694553375},
#  {'label': 'joy', 'score': 0.04794260486960411},
#  {'label': 'anger', 'score': 0.009156367741525173},
#  {'label': 'disgust', 'score': 0.0026284796185791492},
#  {'label': 'sadness', 'score': 0.0021221658680588007}]

# %%
sorted(predictions[0], key=lambda x: x["label"])
# Out:
# [{'label': 'anger', 'score': 0.009156367741525173},
#  {'label': 'disgust', 'score': 0.0026284796185791492},
#  {'label': 'fear', 'score': 0.06816233694553375},
#  {'label': 'joy', 'score': 0.04794260486960411},
#  {'label': 'neutral', 'score': 0.14038586616516113},
#  {'label': 'sadness', 'score': 0.0021221658680588007},
#  {'label': 'surprise', 'score': 0.7296021580696106}]

# %%
import numpy as np

# List of emotion labels in the exact order you want to store scores.
# This ordering is important because sorting predictions alphabetically
# must match this list's order.
emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []

# Dictionary to hold scores for each emotion 
emotion_scores = {label: [] for label in emotion_labels}

def calculate_max_emotion_scores(predictions):
    """
    Takes a list of predictions (each prediction is a list of emotion-score dictionaries)
    and returns the highest score seen for each emotion across all predictions.
    
    Example of one prediction:
    [
        {"label": "joy", "score": 0.55},
        {"label": "anger", "score": 0.03},
        ...
    ]
    
    The function:
    1. Sorts each prediction alphabetically by emotion label.
    2. Aligns scores with 'emotion_labels' list.
    3. Collects all scores per emotion.
    4. Returns the maximum score for each emotion.
    """
    
    per_emotion_scores = {label: [] for label in emotion_labels} 
    for prediction in predictions:
        sorted_predictions = sorted(prediction, key=lambda x: x["label"])
        for index, label in enumerate(emotion_labels):
            per_emotion_scores[label].append(sorted_predictions[index]["score"])
    return {label: np.max(scores) for label, scores in per_emotion_scores.items()}

# %%
for i in range(10):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])

# %%
emotion_scores
# Out:
# {'anger': [np.float64(0.06413359194993973),
#   np.float64(0.6126194596290588),
#   np.float64(0.06413359194993973),
#   np.float64(0.3514842092990875),
#   np.float64(0.08141259849071503),
#   np.float64(0.23222461342811584),
#   np.float64(0.5381842851638794),
#   np.float64(0.06413359194993973),
#   np.float64(0.30066993832588196),
#   np.float64(0.06413359194993973)],
#  'disgust': [np.float64(0.2735915184020996),
#   np.float64(0.3482845425605774),
#   np.float64(0.10400668531656265),
#   np.float64(0.15072239935398102),
#   np.float64(0.18449528515338898),
#   np.float64(0.7271749973297119),
#   np.float64(0.15585505962371826),
#   np.float64(0.10400668531656265),
#   np.float64(0.2794816195964813),
#   np.float64(0.17792613804340363)],
#  'fear': [np.float64(0.9281682372093201),
#   np.float64(0.9425276517868042),
#   np.float64(0.9723208546638489),
#   np.float64(0.3607059419155121),
#   np.float64(0.09504329413175583),
#   np.float64(0.05136280506849289),
# ...

# %%
from tqdm import tqdm

emotion_labels = ["anger", "disgust", "fear", "joy", "sadness", "surprise", "neutral"]
isbn = []
emotion_scores = {label: [] for label in emotion_labels}

for i in tqdm(range(len(books))):
    isbn.append(books["isbn13"][i])
    sentences = books["description"][i].split(".")
    predictions = classifier(sentences)
    max_scores = calculate_max_emotion_scores(predictions)
    for label in emotion_labels:
        emotion_scores[label].append(max_scores[label])
# Out:
# 100%|██████████| 5197/5197 [12:46<00:00,  6.78it/s]

# %%
emotions_df = pd.DataFrame(emotion_scores)
emotions_df["isbn13"] = isbn
emotions_df
# Out:
#          anger   disgust      fear       joy   sadness  surprise   neutral  \
# 0     0.064134  0.273592  0.928168  0.932798  0.646216  0.967158  0.729602
# 1     0.612619  0.348285  0.942528  0.704422  0.887940  0.111690  0.252546
# 2     0.064134  0.104007  0.972321  0.767238  0.549477  0.111690  0.078765
# 3     0.351484  0.150722  0.360706  0.251881  0.732685  0.111690  0.078765
# 4     0.081413  0.184495  0.095043  0.040564  0.884390  0.475881  0.078765
# ...        ...       ...       ...       ...       ...       ...       ...
# 5192  0.148209  0.030643  0.919165  0.255173  0.853721  0.980877  0.030656
# 5193  0.064134  0.114383  0.051363  0.400263  0.883198  0.111690  0.227765
# 5194  0.009997  0.009929  0.339218  0.947779  0.375754  0.066685  0.057625
# 5195  0.064134  0.104007  0.459269  0.759457  0.951104  0.368111  0.078765
# 5196  0.064134  0.104007  0.051363  0.958549  0.915193  0.111690  0.078765
#
#              isbn13
# 0     9780002005883
# 1     9780002261982
# ...

# %%
books = pd.merge(books, emotions_df, on = "isbn13")
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# ...

# %%
books.to_csv("books_with_emotions.csv", index = False)
