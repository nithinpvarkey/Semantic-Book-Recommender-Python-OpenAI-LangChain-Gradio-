# %%
import os
os.environ["TQDM_DISABLE"] = "1"                # disable tqdm globally
os.environ["HF_HUB_DISABLE_PROGRESS_BARS"] = "1" # disable HF model/download bars
os.environ["TOKENIZERS_PARALLELISM"] = "false"   # avoids extra worker noise

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from tqdm import tqdm

# %%
import pandas as pd
books = pd.read_csv('books_cleaned.csv')
books
# Out:
#              isbn13      isbn10  \
# 0     9780002005883  0002005883
# 1     9780002261982  0002261987
# 2     9780006178736  0006178731
# 3     9780006280897  0006280897
# 4     9780006280934  0006280935
# ...             ...         ...
# 5192  9788172235222  8172235224
# 5193  9788173031014  8173031010
# 5194  9788179921623  817992162X
# 5195  9788185300535  8185300534
# 5196  9789027712059  9027712050
#
#                                                   title  \
# 0                                                Gilead
# 1                                          Spider's Web
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195                                          I Am that
# 5196                           The Berlin Phenomenology
#
#                                            authors  \
# 0                               Marilynne Robinson
# 1                  Charles Osborne;Agatha Christie
# 2                                   Sidney Sheldon
# 3                              Clive Staples Lewis
# 4                              Clive Staples Lewis
# ...                                            ...
# 5192                              Nayantara Sahgal
# 5193                                 Hermann Hesse
# 5194                                  Robin Sharma
# 5195  Sri Nisargadatta Maharaj;Sudhakar S. Dikshit
# 5196                 Georg Wilhelm Friedrich Hegel
#
#                          categories  \
# 0                           Fiction
# 1     Detective and mystery stories
# 2                           Fiction
# 3                    Christian life
# 4                    Christian life
# ...                             ...
# 5192        Indic fiction (English)
# 5193              Adventure stories
# 5194               Health & Fitness
# 5195                     Philosophy
# 5196                        History
#
#                                               thumbnail  \
# 0     http://books.google.com/books/content?id=KQZCP...
# 1     http://books.google.com/books/content?id=gA5GP...
# 2     http://books.google.com/books/content?id=FKo2T...
# 3     http://books.google.com/books/content?id=XhQ5X...
# 4     http://books.google.com/books/content?id=Kk-uV...
# ...                                                 ...
# 5192  http://books.google.com/books/content?id=q-tKP...
# 5193  http://books.google.com/books/content?id=rq6JP...
# 5194  http://books.google.com/books/content?id=c_7mf...
# 5195  http://books.google.com/books/content?id=Fv_JP...
# 5196  http://books.google.com/books/content?id=Vy7Sk...
#
#                                             description  published_year  \
# 0     A NOVEL THAT READERS and critics have been eag...          2004.0
# 1     A new 'Christie for Christmas' -- a full-lengt...          2000.0
# 2     A memorable, mesmerizing heroine Jennifer -- b...          1993.0
# 3     Lewis' work on the nature of love divides love...          2002.0
# 4     "In The Problem of Pain, C.S. Lewis, one of th...          2002.0
# ...                                                 ...             ...
# 5192  On A Train Journey Home To North India After L...          2003.0
# 5193  This book tells the tale of a man who goes on ...          2002.0
# 5194  Wisdom to Create a Life of Passion, Purpose, a...          2003.0
# 5195  This collection of the timeless teachings of o...          1999.0
# 5196  Since the three volume edition ofHegel's Philo...          1981.0
#
#       average_rating  num_pages  ratings_count  \
# 0               3.85      247.0          361.0
# 1               3.83      241.0         5164.0
# 2               3.93      512.0        29532.0
# 3               4.15      170.0        33684.0
# 4               4.09      176.0        37569.0
# ...              ...        ...            ...
# 5192            2.93      324.0            0.0
# 5193            3.70      175.0           24.0
# 5194            3.82      198.0         1568.0
# 5195            4.51      531.0          104.0
# 5196            0.00      210.0            0.0
#
#                                      title_and_subtitle  \
# 0                                                Gilead
# 1                                 Spider's Web: A Novel
# 2                                        Rage of angels
# 3                                        The Four Loves
# 4                                   The Problem of Pain
# ...                                                 ...
# 5192                                  Mistaken Identity
# 5193                                Journey to the East
# 5194  The Monk Who Sold His Ferrari: A Fable About F...
# 5195     I Am that: Talks with Sri Nisargadatta Maharaj
# 5196                           The Berlin Phenomenology
#
#                                      tagged_description
# 0     9780002005883 A NOVEL THAT READERS and critics...
# 1     9780002261982 A new 'Christie for Christmas' -...
# 2     9780006178736 A memorable, mesmerizing heroine...
# 3     9780006280897 Lewis' work on the nature of lov...
# 4     9780006280934 "In The Problem of Pain, C.S. Le...
# ...                                                 ...
# 5192  9788172235222 On A Train Journey Home To North...
# 5193  9788173031014 This book tells the tale of a ma...
# 5194  9788179921623 Wisdom to Create a Life of Passi...
# 5195  9788185300535 This collection of the timeless ...
# 5196  9789027712059 Since the three volume edition o...
#
# [5197 rows x 13 columns]

# %%
books['tagged_description']
# Out:
# 0       9780002005883 A NOVEL THAT READERS and critics...
# 1       9780002261982 A new 'Christie for Christmas' -...
# 2       9780006178736 A memorable, mesmerizing heroine...
# 3       9780006280897 Lewis' work on the nature of lov...
# 4       9780006280934 "In The Problem of Pain, C.S. Le...
#                               ...
# 5192    9788172235222 On A Train Journey Home To North...
# 5193    9788173031014 This book tells the tale of a ma...
# 5194    9788179921623 Wisdom to Create a Life of Passi...
# 5195    9788185300535 This collection of the timeless ...
# 5196    9789027712059 Since the three volume edition o...
# Name: tagged_description, Length: 5197, dtype: object

# %%
# convert tagged_description to a text file since langchain is not good with pandas dataframe
books["tagged_description"].to_csv('tagged_description.txt',
                                   sep = '\n',
                                   index = False,
                                   header = False)

# %%
raw_documents = TextLoader('tagged_description.txt').load()
text_splitter = CharacterTextSplitter(chunk_size=800, chunk_overlap=0, separator="\n")
documents = text_splitter.split_documents(raw_documents)
# Out:
# Created a chunk of size 1168, which is longer than the specified 800
# Created a chunk of size 1214, which is longer than the specified 800
# Created a chunk of size 960, which is longer than the specified 800
# Created a chunk of size 843, which is longer than the specified 800
# Created a chunk of size 881, which is longer than the specified 800
# Created a chunk of size 1088, which is longer than the specified 800
# Created a chunk of size 1189, which is longer than the specified 800
# Created a chunk of size 1267, which is longer than the specified 800
# Created a chunk of size 887, which is longer than the specified 800
# Created a chunk of size 2010, which is longer than the specified 800
# Created a chunk of size 1225, which is longer than the specified 800
# Created a chunk of size 1184, which is longer than the specified 800
# Created a chunk of size 1214, which is longer than the specified 800
# Created a chunk of size 1191, which is longer than the specified 800
# Created a chunk of size 1057, which is longer than the specified 800
# Created a chunk of size 876, which is longer than the specified 800
# Created a chunk of size 899, which is longer than the specified 800
# Created a chunk of size 1270, which is longer than the specified 800
# Created a chunk of size 1635, which is longer than the specified 800
# Created a chunk of size 958, which is longer than the specified 800
# Created a chunk of size 1132, which is longer than the specified 800
# Created a chunk of size 1325, which is longer than the specified 800
# Created a chunk of size 851, which is longer than the specified 800
# Created a chunk of size 801, which is longer than the specified 800
# Created a chunk of size 1119, which is longer than the specified 800
# Created a chunk of size 836, which is longer than the specified 800
# Created a chunk of size 1195, which is longer than the specified 800
# Created a chunk of size 2012, which is longer than the specified 800
# Created a chunk of size 1286, which is longer than the specified 800
# Created a chunk of size 1231, which is longer than the specified 800
# Created a chunk of size 1242, which is longer than the specified 800
# Created a chunk of size 912, which is longer than the specified 800
# Created a chunk of size 844, which is longer than the specified 800
# Created a chunk of size 1126, which is longer than the specified 800
# Created a chunk of size 1073, which is longer than the specified 800
# Created a chunk of size 1318, which is longer than the specified 800
# Created a chunk of size 2834, which is longer than the specified 800
# Created a chunk of size 1141, which is longer than the specified 800
# Created a chunk of size 1004, which is longer than the specified 800
# Created a chunk of size 2510, which is longer than the specified 800
# Created a chunk of size 954, which is longer than the specified 800
# Created a chunk of size 1422, which is longer than the specified 800
# Created a chunk of size 1083, which is longer than the specified 800
# Created a chunk of size 1144, which is longer than the specified 800
# Created a chunk of size 1268, which is longer than the specified 800
# Created a chunk of size 1086, which is longer than the specified 800
# Created a chunk of size 874, which is longer than the specified 800
# Created a chunk of size 876, which is longer than the specified 800
# Created a chunk of size 806, which is longer than the specified 800
# Created a chunk of size 1812, which is longer than the specified 800
# Created a chunk of size 1830, which is longer than the specified 800
# Created a chunk of size 1064, which is longer than the specified 800
# Created a chunk of size 955, which is longer than the specified 800
# Created a chunk of size 1180, which is longer than the specified 800
# Created a chunk of size 1284, which is longer than the specified 800
# Created a chunk of size 1642, which is longer than the specified 800
# Created a chunk of size 1930, which is longer than the specified 800
# Created a chunk of size 872, which is longer than the specified 800
# Created a chunk of size 2008, which is longer than the specified 800
# Created a chunk of size 2285, which is longer than the specified 800
# Created a chunk of size 1003, which is longer than the specified 800
# Created a chunk of size 1142, which is longer than the specified 800
# Created a chunk of size 1143, which is longer than the specified 800
# Created a chunk of size 1086, which is longer than the specified 800
# Created a chunk of size 1483, which is longer than the specified 800
# Created a chunk of size 1135, which is longer than the specified 800
# Created a chunk of size 965, which is longer than the specified 800
# Created a chunk of size 857, which is longer than the specified 800
# Created a chunk of size 1032, which is longer than the specified 800
# Created a chunk of size 1015, which is longer than the specified 800
# Created a chunk of size 970, which is longer than the specified 800
# Created a chunk of size 931, which is longer than the specified 800
# Created a chunk of size 854, which is longer than the specified 800
# Created a chunk of size 1088, which is longer than the specified 800
# Created a chunk of size 1912, which is longer than the specified 800
# Created a chunk of size 2616, which is longer than the specified 800
# Created a chunk of size 1580, which is longer than the specified 800
# Created a chunk of size 994, which is longer than the specified 800
# Created a chunk of size 847, which is longer than the specified 800
# Created a chunk of size 1530, which is longer than the specified 800
# Created a chunk of size 2030, which is longer than the specified 800
# Created a chunk of size 1619, which is longer than the specified 800
# Created a chunk of size 822, which is longer than the specified 800
# Created a chunk of size 843, which is longer than the specified 800
# Created a chunk of size 1189, which is longer than the specified 800
# Created a chunk of size 1282, which is longer than the specified 800
# Created a chunk of size 1268, which is longer than the specified 800
# Created a chunk of size 1277, which is longer than the specified 800
# Created a chunk of size 1056, which is longer than the specified 800
# Created a chunk of size 969, which is longer than the specified 800
# Created a chunk of size 963, which is longer than the specified 800
# Created a chunk of size 843, which is longer than the specified 800
# Created a chunk of size 984, which is longer than the specified 800
# Created a chunk of size 1163, which is longer than the specified 800
# Created a chunk of size 1058, which is longer than the specified 800
# Created a chunk of size 875, which is longer than the specified 800
# Created a chunk of size 817, which is longer than the specified 800
# Created a chunk of size 868, which is longer than the specified 800
# Created a chunk of size 1084, which is longer than the specified 800
# Created a chunk of size 2762, which is longer than the specified 800
# Created a chunk of size 1033, which is longer than the specified 800
# Created a chunk of size 1010, which is longer than the specified 800
# Created a chunk of size 1064, which is longer than the specified 800
# Created a chunk of size 1224, which is longer than the specified 800
# Created a chunk of size 1805, which is longer than the specified 800
# Created a chunk of size 1017, which is longer than the specified 800
# Created a chunk of size 922, which is longer than the specified 800
# Created a chunk of size 967, which is longer than the specified 800
# Created a chunk of size 854, which is longer than the specified 800
# Created a chunk of size 854, which is longer than the specified 800
# Created a chunk of size 927, which is longer than the specified 800
# Created a chunk of size 1268, which is longer than the specified 800
# Created a chunk of size 868, which is longer than the specified 800
# Created a chunk of size 931, which is longer than the specified 800
# Created a chunk of size 1771, which is longer than the specified 800
# Created a chunk of size 824, which is longer than the specified 800
# Created a chunk of size 969, which is longer than the specified 800
# Created a chunk of size 844, which is longer than the specified 800
# Created a chunk of size 876, which is longer than the specified 800
# Created a chunk of size 1270, which is longer than the specified 800
# Created a chunk of size 1019, which is longer than the specified 800
# Created a chunk of size 857, which is longer than the specified 800
# Created a chunk of size 848, which is longer than the specified 800
# Created a chunk of size 1177, which is longer than the specified 800
# Created a chunk of size 904, which is longer than the specified 800
# Created a chunk of size 852, which is longer than the specified 800
# Created a chunk of size 1715, which is longer than the specified 800
# Created a chunk of size 845, which is longer than the specified 800
# Created a chunk of size 1681, which is longer than the specified 800
# Created a chunk of size 991, which is longer than the specified 800
# Created a chunk of size 1128, which is longer than the specified 800
# Created a chunk of size 2005, which is longer than the specified 800
# Created a chunk of size 1171, which is longer than the specified 800
# Created a chunk of size 2141, which is longer than the specified 800
# Created a chunk of size 1322, which is longer than the specified 800
# Created a chunk of size 1112, which is longer than the specified 800
# Created a chunk of size 908, which is longer than the specified 800
# Created a chunk of size 1316, which is longer than the specified 800
# Created a chunk of size 950, which is longer than the specified 800
# Created a chunk of size 1121, which is longer than the specified 800
# Created a chunk of size 1018, which is longer than the specified 800
# Created a chunk of size 1007, which is longer than the specified 800
# Created a chunk of size 884, which is longer than the specified 800
# Created a chunk of size 911, which is longer than the specified 800
# Created a chunk of size 1057, which is longer than the specified 800
# Created a chunk of size 1255, which is longer than the specified 800
# Created a chunk of size 1098, which is longer than the specified 800
# Created a chunk of size 907, which is longer than the specified 800
# Created a chunk of size 877, which is longer than the specified 800
# Created a chunk of size 1143, which is longer than the specified 800
# Created a chunk of size 877, which is longer than the specified 800
# Created a chunk of size 841, which is longer than the specified 800
# Created a chunk of size 921, which is longer than the specified 800
# Created a chunk of size 809, which is longer than the specified 800
# Created a chunk of size 1550, which is longer than the specified 800
# Created a chunk of size 827, which is longer than the specified 800
# Created a chunk of size 877, which is longer than the specified 800
# Created a chunk of size 923, which is longer than the specified 800
# Created a chunk of size 1652, which is longer than the specified 800
# Created a chunk of size 873, which is longer than the specified 800
# Created a chunk of size 1495, which is longer than the specified 800
# Created a chunk of size 976, which is longer than the specified 800
# Created a chunk of size 926, which is longer than the specified 800
# Created a chunk of size 991, which is longer than the specified 800
# Created a chunk of size 832, which is longer than the specified 800
# Created a chunk of size 824, which is longer than the specified 800
# Created a chunk of size 886, which is longer than the specified 800
# Created a chunk of size 1277, which is longer than the specified 800
# Created a chunk of size 847, which is longer than the specified 800
# Created a chunk of size 1046, which is longer than the specified 800
# Created a chunk of size 914, which is longer than the specified 800
# Created a chunk of size 945, which is longer than the specified 800
# Created a chunk of size 905, which is longer than the specified 800
# Created a chunk of size 847, which is longer than the specified 800
# Created a chunk of size 865, which is longer than the specified 800
# Created a chunk of size 802, which is longer than the specified 800
# Created a chunk of size 837, which is longer than the specified 800
# Created a chunk of size 864, which is longer than the specified 800
# Created a chunk of size 816, which is longer than the specified 800
# Created a chunk of size 990, which is longer than the specified 800
# Created a chunk of size 994, which is longer than the specified 800
# Created a chunk of size 1666, which is longer than the specified 800
# Created a chunk of size 1616, which is longer than the specified 800
# Created a chunk of size 816, which is longer than the specified 800
# Created a chunk of size 1095, which is longer than the specified 800
# Created a chunk of size 1597, which is longer than the specified 800
# Created a chunk of size 944, which is longer than the specified 800
# Created a chunk of size 1960, which is longer than the specified 800
# Created a chunk of size 1708, which is longer than the specified 800
# Created a chunk of size 895, which is longer than the specified 800
# Created a chunk of size 994, which is longer than the specified 800
# Created a chunk of size 1947, which is longer than the specified 800
# Created a chunk of size 1027, which is longer than the specified 800
# Created a chunk of size 1807, which is longer than the specified 800
# Created a chunk of size 1518, which is longer than the specified 800
# Created a chunk of size 809, which is longer than the specified 800
# Created a chunk of size 869, which is longer than the specified 800
# Created a chunk of size 890, which is longer than the specified 800
# Created a chunk of size 1087, which is longer than the specified 800
# Created a chunk of size 1093, which is longer than the specified 800
# Created a chunk of size 878, which is longer than the specified 800
# Created a chunk of size 979, which is longer than the specified 800
# Created a chunk of size 988, which is longer than the specified 800
# Created a chunk of size 1167, which is longer than the specified 800
# Created a chunk of size 1259, which is longer than the specified 800
# Created a chunk of size 1480, which is longer than the specified 800
# Created a chunk of size 816, which is longer than the specified 800
# Created a chunk of size 1037, which is longer than the specified 800
# Created a chunk of size 1085, which is longer than the specified 800
# Created a chunk of size 1443, which is longer than the specified 800
# Created a chunk of size 1266, which is longer than the specified 800
# Created a chunk of size 1144, which is longer than the specified 800
# Created a chunk of size 1369, which is longer than the specified 800
# Created a chunk of size 1622, which is longer than the specified 800
# Created a chunk of size 1165, which is longer than the specified 800
# Created a chunk of size 1176, which is longer than the specified 800
# Created a chunk of size 1179, which is longer than the specified 800
# Created a chunk of size 826, which is longer than the specified 800
# Created a chunk of size 998, which is longer than the specified 800
# Created a chunk of size 1009, which is longer than the specified 800
# Created a chunk of size 1022, which is longer than the specified 800
# Created a chunk of size 1357, which is longer than the specified 800
# Created a chunk of size 813, which is longer than the specified 800
# Created a chunk of size 1172, which is longer than the specified 800
# Created a chunk of size 1394, which is longer than the specified 800
# Created a chunk of size 1216, which is longer than the specified 800
# Created a chunk of size 2209, which is longer than the specified 800
# Created a chunk of size 1371, which is longer than the specified 800
# Created a chunk of size 2877, which is longer than the specified 800
# Created a chunk of size 1279, which is longer than the specified 800
# Created a chunk of size 1714, which is longer than the specified 800
# Created a chunk of size 1638, which is longer than the specified 800
# Created a chunk of size 2398, which is longer than the specified 800
# Created a chunk of size 825, which is longer than the specified 800
# Created a chunk of size 2120, which is longer than the specified 800
# Created a chunk of size 1488, which is longer than the specified 800
# Created a chunk of size 1691, which is longer than the specified 800
# Created a chunk of size 843, which is longer than the specified 800
# Created a chunk of size 1418, which is longer than the specified 800
# Created a chunk of size 1173, which is longer than the specified 800
# Created a chunk of size 1359, which is longer than the specified 800
# Created a chunk of size 826, which is longer than the specified 800
# Created a chunk of size 915, which is longer than the specified 800
# Created a chunk of size 2181, which is longer than the specified 800
# Created a chunk of size 1093, which is longer than the specified 800
# Created a chunk of size 2171, which is longer than the specified 800
# Created a chunk of size 1454, which is longer than the specified 800
# Created a chunk of size 1454, which is longer than the specified 800
# Created a chunk of size 1973, which is longer than the specified 800
# Created a chunk of size 1987, which is longer than the specified 800
# Created a chunk of size 1648, which is longer than the specified 800
# Created a chunk of size 2723, which is longer than the specified 800
# Created a chunk of size 1632, which is longer than the specified 800
# Created a chunk of size 938, which is longer than the specified 800
# Created a chunk of size 1284, which is longer than the specified 800
# Created a chunk of size 1484, which is longer than the specified 800
# Created a chunk of size 1049, which is longer than the specified 800
# Created a chunk of size 1003, which is longer than the specified 800
# Created a chunk of size 1150, which is longer than the specified 800
# Created a chunk of size 1216, which is longer than the specified 800
# Created a chunk of size 899, which is longer than the specified 800
# Created a chunk of size 945, which is longer than the specified 800
# Created a chunk of size 1032, which is longer than the specified 800
# Created a chunk of size 2456, which is longer than the specified 800
# Created a chunk of size 983, which is longer than the specified 800
# Created a chunk of size 1349, which is longer than the specified 800
# Created a chunk of size 1271, which is longer than the specified 800
# Created a chunk of size 1117, which is longer than the specified 800
# Created a chunk of size 1548, which is longer than the specified 800
# Created a chunk of size 1201, which is longer than the specified 800
# Created a chunk of size 975, which is longer than the specified 800
# Created a chunk of size 996, which is longer than the specified 800
# Created a chunk of size 1160, which is longer than the specified 800
# Created a chunk of size 1149, which is longer than the specified 800
# Created a chunk of size 837, which is longer than the specified 800
# Created a chunk of size 964, which is longer than the specified 800
# Created a chunk of size 1024, which is longer than the specified 800
# Created a chunk of size 1774, which is longer than the specified 800
# Created a chunk of size 1165, which is longer than the specified 800
# Created a chunk of size 1009, which is longer than the specified 800
# Created a chunk of size 1017, which is longer than the specified 800
# Created a chunk of size 1323, which is longer than the specified 800
# Created a chunk of size 1213, which is longer than the specified 800
# Created a chunk of size 909, which is longer than the specified 800
# Created a chunk of size 1123, which is longer than the specified 800
# Created a chunk of size 1598, which is longer than the specified 800
# Created a chunk of size 1963, which is longer than the specified 800
# Created a chunk of size 894, which is longer than the specified 800
# Created a chunk of size 940, which is longer than the specified 800
# Created a chunk of size 2450, which is longer than the specified 800
# Created a chunk of size 1796, which is longer than the specified 800
# Created a chunk of size 1568, which is longer than the specified 800
# Created a chunk of size 1219, which is longer than the specified 800
# Created a chunk of size 880, which is longer than the specified 800
# Created a chunk of size 1380, which is longer than the specified 800
# Created a chunk of size 854, which is longer than the specified 800
# Created a chunk of size 1452, which is longer than the specified 800
# Created a chunk of size 1102, which is longer than the specified 800
# Created a chunk of size 1298, which is longer than the specified 800
# Created a chunk of size 907, which is longer than the specified 800
# Created a chunk of size 993, which is longer than the specified 800
# Created a chunk of size 1761, which is longer than the specified 800
# Created a chunk of size 1004, which is longer than the specified 800
# Created a chunk of size 1022, which is longer than the specified 800
# Created a chunk of size 923, which is longer than the specified 800
# Created a chunk of size 1064, which is longer than the specified 800
# Created a chunk of size 868, which is longer than the specified 800
# Created a chunk of size 1009, which is longer than the specified 800
# Created a chunk of size 880, which is longer than the specified 800
# Created a chunk of size 988, which is longer than the specified 800
# Created a chunk of size 1064, which is longer than the specified 800
# Created a chunk of size 1629, which is longer than the specified 800
# Created a chunk of size 1593, which is longer than the specified 800
# Created a chunk of size 825, which is longer than the specified 800
# Created a chunk of size 1587, which is longer than the specified 800
# Created a chunk of size 1259, which is longer than the specified 800
# Created a chunk of size 1128, which is longer than the specified 800
# Created a chunk of size 1105, which is longer than the specified 800
# Created a chunk of size 848, which is longer than the specified 800
# Created a chunk of size 949, which is longer than the specified 800
# Created a chunk of size 847, which is longer than the specified 800
# Created a chunk of size 971, which is longer than the specified 800
# Created a chunk of size 1080, which is longer than the specified 800
# Created a chunk of size 1533, which is longer than the specified 800
# Created a chunk of size 823, which is longer than the specified 800
# Created a chunk of size 1202, which is longer than the specified 800
# Created a chunk of size 1093, which is longer than the specified 800
# Created a chunk of size 1247, which is longer than the specified 800
# Created a chunk of size 1056, which is longer than the specified 800
# Created a chunk of size 1211, which is longer than the specified 800
# Created a chunk of size 930, which is longer than the specified 800
# Created a chunk of size 1011, which is longer than the specified 800
# Created a chunk of size 996, which is longer than the specified 800
# Created a chunk of size 1352, which is longer than the specified 800
# Created a chunk of size 1412, which is longer than the specified 800
# Created a chunk of size 877, which is longer than the specified 800
# Created a chunk of size 1023, which is longer than the specified 800
# Created a chunk of size 1216, which is longer than the specified 800
# Created a chunk of size 836, which is longer than the specified 800
# Created a chunk of size 1131, which is longer than the specified 800
# Created a chunk of size 985, which is longer than the specified 800
# Created a chunk of size 804, which is longer than the specified 800
# Created a chunk of size 956, which is longer than the specified 800
# Created a chunk of size 885, which is longer than the specified 800
# Created a chunk of size 1197, which is longer than the specified 800
# Created a chunk of size 1891, which is longer than the specified 800
# Created a chunk of size 3168, which is longer than the specified 800
# Created a chunk of size 1532, which is longer than the specified 800
# Created a chunk of size 1588, which is longer than the specified 800
# Created a chunk of size 962, which is longer than the specified 800
# Created a chunk of size 1609, which is longer than the specified 800
# Created a chunk of size 1623, which is longer than the specified 800
# Created a chunk of size 1419, which is longer than the specified 800
# Created a chunk of size 1114, which is longer than the specified 800
# Created a chunk of size 1128, which is longer than the specified 800
# Created a chunk of size 1036, which is longer than the specified 800
# Created a chunk of size 1139, which is longer than the specified 800
# Created a chunk of size 1178, which is longer than the specified 800
# Created a chunk of size 1048, which is longer than the specified 800
# Created a chunk of size 835, which is longer than the specified 800
# Created a chunk of size 1000, which is longer than the specified 800
# Created a chunk of size 970, which is longer than the specified 800
# Created a chunk of size 1211, which is longer than the specified 800
# Created a chunk of size 882, which is longer than the specified 800
# Created a chunk of size 846, which is longer than the specified 800
# Created a chunk of size 949, which is longer than the specified 800
# Created a chunk of size 1169, which is longer than the specified 800
# Created a chunk of size 842, which is longer than the specified 800
# Created a chunk of size 949, which is longer than the specified 800
# Created a chunk of size 2034, which is longer than the specified 800
# Created a chunk of size 992, which is longer than the specified 800
# Created a chunk of size 1115, which is longer than the specified 800
# Created a chunk of size 1436, which is longer than the specified 800
# Created a chunk of size 1113, which is longer than the specified 800
# Created a chunk of size 925, which is longer than the specified 800
# Created a chunk of size 888, which is longer than the specified 800
# Created a chunk of size 848, which is longer than the specified 800
# Created a chunk of size 874, which is longer than the specified 800
# Created a chunk of size 845, which is longer than the specified 800
# Created a chunk of size 962, which is longer than the specified 800
# Created a chunk of size 978, which is longer than the specified 800
# Created a chunk of size 1062, which is longer than the specified 800
# Created a chunk of size 984, which is longer than the specified 800
# Created a chunk of size 994, which is longer than the specified 800
# Created a chunk of size 931, which is longer than the specified 800
# Created a chunk of size 1471, which is longer than the specified 800
# Created a chunk of size 1436, which is longer than the specified 800
# Created a chunk of size 949, which is longer than the specified 800
# Created a chunk of size 834, which is longer than the specified 800
# Created a chunk of size 1330, which is longer than the specified 800
# Created a chunk of size 1721, which is longer than the specified 800
# Created a chunk of size 952, which is longer than the specified 800
# Created a chunk of size 1530, which is longer than the specified 800
# Created a chunk of size 985, which is longer than the specified 800
# Created a chunk of size 1651, which is longer than the specified 800
# Created a chunk of size 809, which is longer than the specified 800
# Created a chunk of size 1579, which is longer than the specified 800
# Created a chunk of size 1646, which is longer than the specified 800
# Created a chunk of size 1687, which is longer than the specified 800
# Created a chunk of size 852, which is longer than the specified 800
# Created a chunk of size 2031, which is longer than the specified 800
# Created a chunk of size 957, which is longer than the specified 800
# Created a chunk of size 832, which is longer than the specified 800
# Created a chunk of size 832, which is longer than the specified 800
# Created a chunk of size 1107, which is longer than the specified 800
# Created a chunk of size 868, which is longer than the specified 800
# Created a chunk of size 1049, which is longer than the specified 800
# Created a chunk of size 853, which is longer than the specified 800
# Created a chunk of size 880, which is longer than the specified 800
# Created a chunk of size 1118, which is longer than the specified 800
# Created a chunk of size 1089, which is longer than the specified 800
# Created a chunk of size 1103, which is longer than the specified 800
# Created a chunk of size 1130, which is longer than the specified 800
# Created a chunk of size 1338, which is longer than the specified 800
# Created a chunk of size 861, which is longer than the specified 800
# Created a chunk of size 1080, which is longer than the specified 800
# Created a chunk of size 1163, which is longer than the specified 800
# Created a chunk of size 1003, which is longer than the specified 800
# Created a chunk of size 879, which is longer than the specified 800
# Created a chunk of size 818, which is longer than the specified 800
# Created a chunk of size 1085, which is longer than the specified 800
# Created a chunk of size 1003, which is longer than the specified 800
# Created a chunk of size 926, which is longer than the specified 800
# Created a chunk of size 1226, which is longer than the specified 800
# Created a chunk of size 932, which is longer than the specified 800
# Created a chunk of size 898, which is longer than the specified 800
# Created a chunk of size 1235, which is longer than the specified 800
# Created a chunk of size 2940, which is longer than the specified 800
# Created a chunk of size 1118, which is longer than the specified 800
# Created a chunk of size 1490, which is longer than the specified 800
# Created a chunk of size 1157, which is longer than the specified 800
# Created a chunk of size 1208, which is longer than the specified 800
# Created a chunk of size 1489, which is longer than the specified 800
# Created a chunk of size 1086, which is longer than the specified 800
# Created a chunk of size 1802, which is longer than the specified 800
# Created a chunk of size 1595, which is longer than the specified 800
# Created a chunk of size 1030, which is longer than the specified 800
# Created a chunk of size 1361, which is longer than the specified 800
# Created a chunk of size 1643, which is longer than the specified 800
# Created a chunk of size 1382, which is longer than the specified 800
# Created a chunk of size 814, which is longer than the specified 800
# Created a chunk of size 1763, which is longer than the specified 800
# Created a chunk of size 911, which is longer than the specified 800
# Created a chunk of size 1971, which is longer than the specified 800
# Created a chunk of size 1240, which is longer than the specified 800
# Created a chunk of size 801, which is longer than the specified 800
# Created a chunk of size 1119, which is longer than the specified 800
# Created a chunk of size 1051, which is longer than the specified 800
# Created a chunk of size 1006, which is longer than the specified 800
# Created a chunk of size 1119, which is longer than the specified 800
# Created a chunk of size 1127, which is longer than the specified 800
# Created a chunk of size 1037, which is longer than the specified 800
# Created a chunk of size 1280, which is longer than the specified 800
# Created a chunk of size 1475, which is longer than the specified 800
# Created a chunk of size 1268, which is longer than the specified 800
# Created a chunk of size 1219, which is longer than the specified 800
# Created a chunk of size 900, which is longer than the specified 800
# Created a chunk of size 1003, which is longer than the specified 800
# Created a chunk of size 826, which is longer than the specified 800
# Created a chunk of size 1045, which is longer than the specified 800
# Created a chunk of size 857, which is longer than the specified 800
# Created a chunk of size 1052, which is longer than the specified 800
# Created a chunk of size 906, which is longer than the specified 800
# Created a chunk of size 1017, which is longer than the specified 800
# Created a chunk of size 806, which is longer than the specified 800
# Created a chunk of size 828, which is longer than the specified 800
# Created a chunk of size 908, which is longer than the specified 800
# Created a chunk of size 856, which is longer than the specified 800
# Created a chunk of size 970, which is longer than the specified 800
# Created a chunk of size 1177, which is longer than the specified 800
# Created a chunk of size 1246, which is longer than the specified 800
# Created a chunk of size 905, which is longer than the specified 800
# Created a chunk of size 1049, which is longer than the specified 800
# Created a chunk of size 1125, which is longer than the specified 800
# Created a chunk of size 1127, which is longer than the specified 800
# Created a chunk of size 1025, which is longer than the specified 800
# Created a chunk of size 882, which is longer than the specified 800
# Created a chunk of size 1290, which is longer than the specified 800
# Created a chunk of size 1091, which is longer than the specified 800
# Created a chunk of size 1564, which is longer than the specified 800
# Created a chunk of size 1149, which is longer than the specified 800
# Created a chunk of size 1214, which is longer than the specified 800
# Created a chunk of size 1215, which is longer than the specified 800
# Created a chunk of size 1066, which is longer than the specified 800
# Created a chunk of size 1081, which is longer than the specified 800
# Created a chunk of size 857, which is longer than the specified 800
# Created a chunk of size 1042, which is longer than the specified 800
# Created a chunk of size 1255, which is longer than the specified 800
# Created a chunk of size 1173, which is longer than the specified 800
# Created a chunk of size 842, which is longer than the specified 800
# Created a chunk of size 875, which is longer than the specified 800
# Created a chunk of size 1075, which is longer than the specified 800
# Created a chunk of size 1263, which is longer than the specified 800
# Created a chunk of size 1620, which is longer than the specified 800
# Created a chunk of size 994, which is longer than the specified 800
# Created a chunk of size 840, which is longer than the specified 800
# Created a chunk of size 1061, which is longer than the specified 800
# Created a chunk of size 1579, which is longer than the specified 800
# Created a chunk of size 1041, which is longer than the specified 800
# Created a chunk of size 827, which is longer than the specified 800
# Created a chunk of size 1045, which is longer than the specified 800
# Created a chunk of size 1450, which is longer than the specified 800
# Created a chunk of size 1443, which is longer than the specified 800
# Created a chunk of size 1285, which is longer than the specified 800
# Created a chunk of size 941, which is longer than the specified 800
# Created a chunk of size 857, which is longer than the specified 800
# Created a chunk of size 1082, which is longer than the specified 800
# Created a chunk of size 1006, which is longer than the specified 800
# Created a chunk of size 1309, which is longer than the specified 800
# Created a chunk of size 886, which is longer than the specified 800
# Created a chunk of size 809, which is longer than the specified 800
# Created a chunk of size 1126, which is longer than the specified 800
# Created a chunk of size 1158, which is longer than the specified 800
# Created a chunk of size 1922, which is longer than the specified 800
# Created a chunk of size 1912, which is longer than the specified 800
# Created a chunk of size 1200, which is longer than the specified 800
# Created a chunk of size 1166, which is longer than the specified 800
# Created a chunk of size 2146, which is longer than the specified 800
# Created a chunk of size 2490, which is longer than the specified 800
# Created a chunk of size 1373, which is longer than the specified 800
# Created a chunk of size 910, which is longer than the specified 800
# Created a chunk of size 1475, which is longer than the specified 800
# Created a chunk of size 841, which is longer than the specified 800
# Created a chunk of size 1965, which is longer than the specified 800
# Created a chunk of size 1621, which is longer than the specified 800
# Created a chunk of size 3784, which is longer than the specified 800
# Created a chunk of size 1055, which is longer than the specified 800
# Created a chunk of size 1446, which is longer than the specified 800
# Created a chunk of size 928, which is longer than the specified 800
# Created a chunk of size 1098, which is longer than the specified 800
# Created a chunk of size 989, which is longer than the specified 800
# Created a chunk of size 1199, which is longer than the specified 800
# Created a chunk of size 1492, which is longer than the specified 800
# Created a chunk of size 2702, which is longer than the specified 800
# Created a chunk of size 5836, which is longer than the specified 800
# Created a chunk of size 1709, which is longer than the specified 800
# Created a chunk of size 1678, which is longer than the specified 800
# Created a chunk of size 1808, which is longer than the specified 800
# Created a chunk of size 1171, which is longer than the specified 800
# Created a chunk of size 1739, which is longer than the specified 800
# Created a chunk of size 1616, which is longer than the specified 800
# Created a chunk of size 1477, which is longer than the specified 800
# Created a chunk of size 1348, which is longer than the specified 800
# Created a chunk of size 1441, which is longer than the specified 800
# Created a chunk of size 1866, which is longer than the specified 800
# Created a chunk of size 1464, which is longer than the specified 800
# Created a chunk of size 1277, which is longer than the specified 800
# Created a chunk of size 997, which is longer than the specified 800
# Created a chunk of size 1086, which is longer than the specified 800
# Created a chunk of size 907, which is longer than the specified 800
# Created a chunk of size 948, which is longer than the specified 800
# Created a chunk of size 1016, which is longer than the specified 800
# Created a chunk of size 1756, which is longer than the specified 800
# Created a chunk of size 1555, which is longer than the specified 800
# Created a chunk of size 1122, which is longer than the specified 800
# Created a chunk of size 1960, which is longer than the specified 800
# Created a chunk of size 2075, which is longer than the specified 800
# Created a chunk of size 1482, which is longer than the specified 800
# Created a chunk of size 904, which is longer than the specified 800
# Created a chunk of size 956, which is longer than the specified 800
# Created a chunk of size 996, which is longer than the specified 800
# Created a chunk of size 804, which is longer than the specified 800
# Created a chunk of size 1469, which is longer than the specified 800
# Created a chunk of size 1370, which is longer than the specified 800
# Created a chunk of size 922, which is longer than the specified 800
# Created a chunk of size 1381, which is longer than the specified 800
# Created a chunk of size 1105, which is longer than the specified 800
# Created a chunk of size 920, which is longer than the specified 800
# Created a chunk of size 1345, which is longer than the specified 800
# Created a chunk of size 900, which is longer than the specified 800
# Created a chunk of size 1144, which is longer than the specified 800
# Created a chunk of size 1099, which is longer than the specified 800
# Created a chunk of size 944, which is longer than the specified 800
# Created a chunk of size 1171, which is longer than the specified 800
# Created a chunk of size 1343, which is longer than the specified 800
# Created a chunk of size 818, which is longer than the specified 800
# Created a chunk of size 1456, which is longer than the specified 800
# Created a chunk of size 1010, which is longer than the specified 800
# Created a chunk of size 2002, which is longer than the specified 800
# Created a chunk of size 1853, which is longer than the specified 800
# Created a chunk of size 1141, which is longer than the specified 800
# Created a chunk of size 1362, which is longer than the specified 800
# Created a chunk of size 1581, which is longer than the specified 800
# Created a chunk of size 1201, which is longer than the specified 800
# Created a chunk of size 1510, which is longer than the specified 800
# Created a chunk of size 1480, which is longer than the specified 800
# Created a chunk of size 1326, which is longer than the specified 800
# Created a chunk of size 897, which is longer than the specified 800
# Created a chunk of size 809, which is longer than the specified 800
# Created a chunk of size 1307, which is longer than the specified 800
# Created a chunk of size 885, which is longer than the specified 800
# Created a chunk of size 1191, which is longer than the specified 800
# Created a chunk of size 994, which is longer than the specified 800
# Created a chunk of size 832, which is longer than the specified 800
# Created a chunk of size 996, which is longer than the specified 800
# Created a chunk of size 1431, which is longer than the specified 800
# Created a chunk of size 1077, which is longer than the specified 800
# Created a chunk of size 1038, which is longer than the specified 800
# Created a chunk of size 1110, which is longer than the specified 800
# Created a chunk of size 1314, which is longer than the specified 800
# Created a chunk of size 958, which is longer than the specified 800
# Created a chunk of size 1415, which is longer than the specified 800
# Created a chunk of size 1863, which is longer than the specified 800
# Created a chunk of size 1379, which is longer than the specified 800
# Created a chunk of size 1519, which is longer than the specified 800
# Created a chunk of size 1078, which is longer than the specified 800
# Created a chunk of size 1432, which is longer than the specified 800
# Created a chunk of size 1246, which is longer than the specified 800
# Created a chunk of size 1549, which is longer than the specified 800
# Created a chunk of size 1064, which is longer than the specified 800
# Created a chunk of size 1172, which is longer than the specified 800
# Created a chunk of size 1094, which is longer than the specified 800
# Created a chunk of size 815, which is longer than the specified 800
# Created a chunk of size 2082, which is longer than the specified 800
# Created a chunk of size 829, which is longer than the specified 800
# Created a chunk of size 855, which is longer than the specified 800
# Created a chunk of size 1248, which is longer than the specified 800
# Created a chunk of size 804, which is longer than the specified 800
# Created a chunk of size 2297, which is longer than the specified 800
# Created a chunk of size 901, which is longer than the specified 800
# Created a chunk of size 988, which is longer than the specified 800
# Created a chunk of size 992, which is longer than the specified 800
# Created a chunk of size 978, which is longer than the specified 800
# Created a chunk of size 984, which is longer than the specified 800
# Created a chunk of size 2071, which is longer than the specified 800
# Created a chunk of size 859, which is longer than the specified 800
# Created a chunk of size 876, which is longer than the specified 800
# Created a chunk of size 849, which is longer than the specified 800
# Created a chunk of size 914, which is longer than the specified 800
# Created a chunk of size 986, which is longer than the specified 800
# Created a chunk of size 1067, which is longer than the specified 800
# Created a chunk of size 976, which is longer than the specified 800
# Created a chunk of size 1428, which is longer than the specified 800
# Created a chunk of size 1017, which is longer than the specified 800
# Created a chunk of size 978, which is longer than the specified 800
# Created a chunk of size 1739, which is longer than the specified 800
# Created a chunk of size 1086, which is longer than the specified 800
# Created a chunk of size 1261, which is longer than the specified 800
# Created a chunk of size 2021, which is longer than the specified 800
# Created a chunk of size 1077, which is longer than the specified 800
# Created a chunk of size 2022, which is longer than the specified 800
# Created a chunk of size 996, which is longer than the specified 800
# Created a chunk of size 1267, which is longer than the specified 800
# Created a chunk of size 1294, which is longer than the specified 800
# Created a chunk of size 1250, which is longer than the specified 800
# Created a chunk of size 1143, which is longer than the specified 800
# Created a chunk of size 1406, which is longer than the specified 800
# Created a chunk of size 1395, which is longer than the specified 800
# Created a chunk of size 1533, which is longer than the specified 800
# Created a chunk of size 1344, which is longer than the specified 800
# Created a chunk of size 1435, which is longer than the specified 800
# Created a chunk of size 1145, which is longer than the specified 800
# Created a chunk of size 1219, which is longer than the specified 800
# Created a chunk of size 1321, which is longer than the specified 800
# Created a chunk of size 1442, which is longer than the specified 800
# Created a chunk of size 1625, which is longer than the specified 800
# Created a chunk of size 901, which is longer than the specified 800
# Created a chunk of size 1162, which is longer than the specified 800
# Created a chunk of size 971, which is longer than the specified 800
# Created a chunk of size 1333, which is longer than the specified 800
# Created a chunk of size 1154, which is longer than the specified 800
# Created a chunk of size 2372, which is longer than the specified 800
# Created a chunk of size 862, which is longer than the specified 800
# Created a chunk of size 1679, which is longer than the specified 800
# Created a chunk of size 996, which is longer than the specified 800
# Created a chunk of size 1107, which is longer than the specified 800
# Created a chunk of size 1193, which is longer than the specified 800
# Created a chunk of size 905, which is longer than the specified 800
# Created a chunk of size 1334, which is longer than the specified 800
# Created a chunk of size 914, which is longer than the specified 800
# Created a chunk of size 1307, which is longer than the specified 800
# Created a chunk of size 1144, which is longer than the specified 800
# Created a chunk of size 1053, which is longer than the specified 800
# Created a chunk of size 927, which is longer than the specified 800
# Created a chunk of size 872, which is longer than the specified 800
# Created a chunk of size 1015, which is longer than the specified 800
# Created a chunk of size 1060, which is longer than the specified 800
# Created a chunk of size 1162, which is longer than the specified 800
# Created a chunk of size 978, which is longer than the specified 800
# Created a chunk of size 816, which is longer than the specified 800
# Created a chunk of size 1069, which is longer than the specified 800
# Created a chunk of size 1981, which is longer than the specified 800
# Created a chunk of size 980, which is longer than the specified 800
# Created a chunk of size 842, which is longer than the specified 800
# Created a chunk of size 1106, which is longer than the specified 800
# Created a chunk of size 864, which is longer than the specified 800
# Created a chunk of size 1627, which is longer than the specified 800
# Created a chunk of size 918, which is longer than the specified 800
# Created a chunk of size 1297, which is longer than the specified 800
# Created a chunk of size 934, which is longer than the specified 800
# Created a chunk of size 1745, which is longer than the specified 800
# Created a chunk of size 1070, which is longer than the specified 800
# Created a chunk of size 915, which is longer than the specified 800
# Created a chunk of size 1086, which is longer than the specified 800
# Created a chunk of size 1024, which is longer than the specified 800
# Created a chunk of size 1201, which is longer than the specified 800
# Created a chunk of size 867, which is longer than the specified 800
# Created a chunk of size 1722, which is longer than the specified 800
# Created a chunk of size 1057, which is longer than the specified 800
# ...
# Created a chunk of size 982, which is longer than the specified 800
# Created a chunk of size 882, which is longer than the specified 800
# Created a chunk of size 993, which is longer than the specified 800
# Created a chunk of size 1174, which is longer than the specified 800
# Created a chunk of size 961, which is longer than the specified 800
# Created a chunk of size 1650, which is longer than the specified 800
# Created a chunk of size 904, which is longer than the specified 800
# Created a chunk of size 1042, which is longer than the specified 800
# Created a chunk of size 1528, which is longer than the specified 800
# Created a chunk of size 1995, which is longer than the specified 800
# Created a chunk of size 988, which is longer than the specified 800
# Created a chunk of size 828, which is longer than the specified 800
# Created a chunk of size 856, which is longer than the specified 800
# Created a chunk of size 1025, which is longer than the specified 800
# Created a chunk of size 939, which is longer than the specified 800
# Created a chunk of size 1352, which is longer than the specified 800
# Created a chunk of size 1400, which is longer than the specified 800
# Created a chunk of size 824, which is longer than the specified 800
# Created a chunk of size 1745, which is longer than the specified 800
# Created a chunk of size 871, which is longer than the specified 800
# Created a chunk of size 2334, which is longer than the specified 800
# Created a chunk of size 2946, which is longer than the specified 800
# Created a chunk of size 804, which is longer than the specified 800
# Created a chunk of size 3243, which is longer than the specified 800
# Created a chunk of size 2780, which is longer than the specified 800
# Created a chunk of size 887, which is longer than the specified 800
# Created a chunk of size 908, which is longer than the specified 800
# Created a chunk of size 1309, which is longer than the specified 800
# Created a chunk of size 1127, which is longer than the specified 800
# Created a chunk of size 1117, which is longer than the specified 800
# Created a chunk of size 1194, which is longer than the specified 800
# Created a chunk of size 832, which is longer than the specified 800
# Created a chunk of size 803, which is longer than the specified 800
# Created a chunk of size 890, which is longer than the specified 800
# Created a chunk of size 2085, which is longer than the specified 800
# Created a chunk of size 1897, which is longer than the specified 800
# Created a chunk of size 875, which is longer than the specified 800
# Created a chunk of size 2018, which is longer than the specified 800
# Created a chunk of size 880, which is longer than the specified 800
# Created a chunk of size 1096, which is longer than the specified 800
# Created a chunk of size 1132, which is longer than the specified 800
# Created a chunk of size 952, which is longer than the specified 800
# Created a chunk of size 844, which is longer than the specified 800
# Created a chunk of size 1933, which is longer than the specified 800
# Created a chunk of size 999, which is longer than the specified 800
# Created a chunk of size 1365, which is longer than the specified 800
# Created a chunk of size 1751, which is longer than the specified 800
# Created a chunk of size 1025, which is longer than the specified 800
# Created a chunk of size 973, which is longer than the specified 800
# Created a chunk of size 838, which is longer than the specified 800
# Created a chunk of size 892, which is longer than the specified 800
# Created a chunk of size 916, which is longer than the specified 800
# Created a chunk of size 935, which is longer than the specified 800
# Created a chunk of size 968, which is longer than the specified 800
# Created a chunk of size 2713, which is longer than the specified 800
# Created a chunk of size 2278, which is longer than the specified 800
# Created a chunk of size 1204, which is longer than the specified 800
# Created a chunk of size 879, which is longer than the specified 800
# Created a chunk of size 1123, which is longer than the specified 800
# Created a chunk of size 1435, which is longer than the specified 800
# Created a chunk of size 1055, which is longer than the specified 800
# Created a chunk of size 1340, which is longer than the specified 800
# Created a chunk of size 1006, which is longer than the specified 800
# Created a chunk of size 883, which is longer than the specified 800
# Created a chunk of size 960, which is longer than the specified 800
# Created a chunk of size 891, which is longer than the specified 800
# Created a chunk of size 1137, which is longer than the specified 800
# Created a chunk of size 2051, which is longer than the specified 800
# Created a chunk of size 1305, which is longer than the specified 800
# Created a chunk of size 2014, which is longer than the specified 800
# Created a chunk of size 928, which is longer than the specified 800
# Created a chunk of size 1045, which is longer than the specified 800
# Created a chunk of size 842, which is longer than the specified 800
# Created a chunk of size 1002, which is longer than the specified 800
# Created a chunk of size 1273, which is longer than the specified 800
# Created a chunk of size 865, which is longer than the specified 800
# Created a chunk of size 906, which is longer than the specified 800
# Created a chunk of size 924, which is longer than the specified 800
# Created a chunk of size 834, which is longer than the specified 800
# Created a chunk of size 901, which is longer than the specified 800
# Created a chunk of size 1360, which is longer than the specified 800
# Created a chunk of size 1731, which is longer than the specified 800
# Created a chunk of size 1054, which is longer than the specified 800
# Created a chunk of size 2067, which is longer than the specified 800
# Created a chunk of size 1326, which is longer than the specified 800
# Created a chunk of size 814, which is longer than the specified 800
# Created a chunk of size 1030, which is longer than the specified 800
# Created a chunk of size 1127, which is longer than the specified 800
# Created a chunk of size 976, which is longer than the specified 800
# Created a chunk of size 1165, which is longer than the specified 800
# Created a chunk of size 1352, which is longer than the specified 800
# Created a chunk of size 1180, which is longer than the specified 800
# Created a chunk of size 1012, which is longer than the specified 800
# Created a chunk of size 1055, which is longer than the specified 800
# Created a chunk of size 1169, which is longer than the specified 800
# Created a chunk of size 938, which is longer than the specified 800
# Created a chunk of size 815, which is longer than the specified 800
# Created a chunk of size 872, which is longer than the specified 800
# Created a chunk of size 1079, which is longer than the specified 800
# Created a chunk of size 1903, which is longer than the specified 800
# Created a chunk of size 988, which is longer than the specified 800
# Created a chunk of size 1310, which is longer than the specified 800
# Created a chunk of size 963, which is longer than the specified 800
# Created a chunk of size 1621, which is longer than the specified 800
# Created a chunk of size 993, which is longer than the specified 800
# Created a chunk of size 871, which is longer than the specified 800
# Created a chunk of size 1163, which is longer than the specified 800
# Created a chunk of size 969, which is longer than the specified 800
# Created a chunk of size 986, which is longer than the specified 800
# Created a chunk of size 1283, which is longer than the specified 800
# Created a chunk of size 1475, which is longer than the specified 800
# Created a chunk of size 1144, which is longer than the specified 800
# Created a chunk of size 1772, which is longer than the specified 800
# Created a chunk of size 1502, which is longer than the specified 800
# Created a chunk of size 1544, which is longer than the specified 800
# Created a chunk of size 2855, which is longer than the specified 800
# Created a chunk of size 1090, which is longer than the specified 800
# Created a chunk of size 963, which is longer than the specified 800
# Created a chunk of size 1132, which is longer than the specified 800
# Created a chunk of size 1197, which is longer than the specified 800
# Created a chunk of size 1172, which is longer than the specified 800
# Created a chunk of size 961, which is longer than the specified 800
# Created a chunk of size 1214, which is longer than the specified 800
# Created a chunk of size 966, which is longer than the specified 800
# Created a chunk of size 881, which is longer than the specified 800
# Created a chunk of size 1002, which is longer than the specified 800
# Created a chunk of size 1472, which is longer than the specified 800
# Created a chunk of size 1471, which is longer than the specified 800
# Created a chunk of size 885, which is longer than the specified 800
# Created a chunk of size 1215, which is longer than the specified 800
# Created a chunk of size 943, which is longer than the specified 800
# Created a chunk of size 1862, which is longer than the specified 800
# Created a chunk of size 1525, which is longer than the specified 800
# Created a chunk of size 1016, which is longer than the specified 800
# Created a chunk of size 1385, which is longer than the specified 800
# Created a chunk of size 1452, which is longer than the specified 800
# Created a chunk of size 1165, which is longer than the specified 800
# Created a chunk of size 927, which is longer than the specified 800
# Created a chunk of size 881, which is longer than the specified 800
# Created a chunk of size 813, which is longer than the specified 800
# Created a chunk of size 945, which is longer than the specified 800
# Created a chunk of size 1003, which is longer than the specified 800
# Created a chunk of size 1360, which is longer than the specified 800
# Created a chunk of size 923, which is longer than the specified 800
# Created a chunk of size 1341, which is longer than the specified 800
# Created a chunk of size 834, which is longer than the specified 800
# Created a chunk of size 1050, which is longer than the specified 800
# Created a chunk of size 1338, which is longer than the specified 800
# Created a chunk of size 1601, which is longer than the specified 800
# Created a chunk of size 1057, which is longer than the specified 800
# Created a chunk of size 1267, which is longer than the specified 800
# Created a chunk of size 1026, which is longer than the specified 800
# Created a chunk of size 823, which is longer than the specified 800
# Created a chunk of size 831, which is longer than the specified 800
# Created a chunk of size 1036, which is longer than the specified 800
# Created a chunk of size 897, which is longer than the specified 800
# Created a chunk of size 1432, which is longer than the specified 800
# Created a chunk of size 873, which is longer than the specified 800
# Created a chunk of size 2869, which is longer than the specified 800
# Created a chunk of size 2347, which is longer than the specified 800
# Created a chunk of size 2451, which is longer than the specified 800
# Created a chunk of size 901, which is longer than the specified 800
# Created a chunk of size 1054, which is longer than the specified 800
# Created a chunk of size 1510, which is longer than the specified 800
# Created a chunk of size 921, which is longer than the specified 800
# Created a chunk of size 1113, which is longer than the specified 800
# Created a chunk of size 1109, which is longer than the specified 800
# Created a chunk of size 922, which is longer than the specified 800
# Created a chunk of size 926, which is longer than the specified 800
# Created a chunk of size 1512, which is longer than the specified 800
# Created a chunk of size 1300, which is longer than the specified 800
# Created a chunk of size 839, which is longer than the specified 800
# Created a chunk of size 1134, which is longer than the specified 800
# Created a chunk of size 1348, which is longer than the specified 800
# Created a chunk of size 954, which is longer than the specified 800
# Created a chunk of size 1084, which is longer than the specified 800
# Created a chunk of size 998, which is longer than the specified 800
# Created a chunk of size 960, which is longer than the specified 800
# Created a chunk of size 856, which is longer than the specified 800
# Created a chunk of size 1108, which is longer than the specified 800
# Created a chunk of size 981, which is longer than the specified 800
# Created a chunk of size 1340, which is longer than the specified 800
# Created a chunk of size 1298, which is longer than the specified 800
# Created a chunk of size 1320, which is longer than the specified 800
# Created a chunk of size 1524, which is longer than the specified 800
# Created a chunk of size 1031, which is longer than the specified 800
# Created a chunk of size 1255, which is longer than the specified 800
# Created a chunk of size 1125, which is longer than the specified 800
# Created a chunk of size 1293, which is longer than the specified 800
# Created a chunk of size 1041, which is longer than the specified 800
# Created a chunk of size 1150, which is longer than the specified 800
# Created a chunk of size 933, which is longer than the specified 800
# Created a chunk of size 880, which is longer than the specified 800
# Created a chunk of size 888, which is longer than the specified 800
# Created a chunk of size 893, which is longer than the specified 800
# Created a chunk of size 909, which is longer than the specified 800
# Created a chunk of size 963, which is longer than the specified 800
# Created a chunk of size 868, which is longer than the specified 800
# Created a chunk of size 905, which is longer than the specified 800
# Created a chunk of size 1155, which is longer than the specified 800
# Created a chunk of size 1350, which is longer than the specified 800
# Created a chunk of size 1403, which is longer than the specified 800
# Created a chunk of size 975, which is longer than the specified 800
# Created a chunk of size 1898, which is longer than the specified 800
# Created a chunk of size 2149, which is longer than the specified 800
# Created a chunk of size 1417, which is longer than the specified 800
# Created a chunk of size 973, which is longer than the specified 800
# Created a chunk of size 1419, which is longer than the specified 800
# Created a chunk of size 840, which is longer than the specified 800
# Created a chunk of size 1387, which is longer than the specified 800
# Created a chunk of size 1280, which is longer than the specified 800
# Created a chunk of size 1287, which is longer than the specified 800
# Created a chunk of size 1043, which is longer than the specified 800
# Created a chunk of size 2742, which is longer than the specified 800
# Created a chunk of size 866, which is longer than the specified 800
# Created a chunk of size 1182, which is longer than the specified 800
# Created a chunk of size 1000, which is longer than the specified 800
# Created a chunk of size 3938, which is longer than the specified 800
# Created a chunk of size 923, which is longer than the specified 800
# Created a chunk of size 853, which is longer than the specified 800
# Created a chunk of size 928, which is longer than the specified 800
# Created a chunk of size 1019, which is longer than the specified 800
# Created a chunk of size 1108, which is longer than the specified 800
# Created a chunk of size 1273, which is longer than the specified 800
# Created a chunk of size 1964, which is longer than the specified 800
# Created a chunk of size 1529, which is longer than the specified 800
# Created a chunk of size 1302, which is longer than the specified 800
# Created a chunk of size 999, which is longer than the specified 800
# Created a chunk of size 1048, which is longer than the specified 800
# Created a chunk of size 1272, which is longer than the specified 800
# Created a chunk of size 950, which is longer than the specified 800
# Created a chunk of size 1655, which is longer than the specified 800
# Created a chunk of size 1032, which is longer than the specified 800

# %%
documents[0]
# Out:
# Document(metadata={'source': 'tagged_description.txt'}, page_content='9780002005883 A NOVEL THAT READERS and critics have been eagerly anticipating for over a decade, Gilead is an astonishingly imagined story of remarkable lives. John Ames is a preacher, the son of a preacher and the grandson (both maternal and paternal) of preachers. It’s 1956 in Gilead, Iowa, towards the end of the Reverend Ames’s life, and he is absorbed in recording his family’s story, a legacy for the young son he will never see grow up. Haunted by his grandfather’s presence, John tells of the rift between his grandfather and his father: the elder, an angry visionary who fought for the abolitionist cause, and his son, an ardent pacifist. He is troubled, too, by his prodigal namesake, Jack (John Ames) Boughton, his best friend’s lost son who returns to Gilead searching for forgiveness and redemption. Told in John Ames’s joyous, rambling voice that finds beauty, humour and truth in the smallest of life’s details, Gilead is a song of celebration and acceptance of the best and the worst the world has to offer. At its heart is a tale of the sacred bonds between fathers and sons, pitch-perfect in style and story, set to dazzle critics and readers alike.')

# %%
emb = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2",
    model_kwargs={'device': 'cpu'},
    encode_kwargs={'normalize_embeddings':True}
    )

db = Chroma.from_documents(
    documents,
    embedding=emb
    )

# %%
query = "A book for soccer lover"
docs = db.similarity_search(query, k = 10)
docs
# Out:
# [Document(id='61faea90-c05d-4177-8fde-312cfefcdcaf', metadata={'source': 'tagged_description.txt'}, page_content='9781573226882 An autobiographical memoir by a humorous British author and obsessed soccer fan captures the intensity of a sports fan who measures his life in seasons rather than years\n9781573227162 A debut novel explores the complications of race through the story of two daughters--one light-skinned and the other dark-skinned--of a black father and a white mother, who become torn apart by racial allegiances. Reprint.\n9781573229623 A memoir of sex, drugs, and depression indicts an overmedicated America as it chronicles the fortunes of a Harvard educated child of divorce who lived in the fast lane as a music critic, always fighting her chronic depression.'),
#  Document(id='7dbd8a07-1124-499b-943f-5998383e7297', metadata={'source': 'tagged_description.txt'}, page_content="9781857442021 Mikhail Tal, the 'magician from Riga, ' was the greatest attacking World Champion of them all, and this enchanting autobiography chronicles his extraordinary career with charm and humor. Dazzling games are interspersed throughout with anecdotes and witty self-interviews, and in typically objective fashion he related both the downs and ups of his encounters. An inveterate smoker and drinker, Tal's life on the circuit was punctuated by bouts in the hospital with kidney problems, but nothing could dull his love for chess and his sheer genius on the chessboard. His illustrious tournament record, up to his death in 1992, is included here in full, along with 100 complete games and nearly as many positions. Tal's annotations in this book are a world apart from ordinary games collections. No reader could fail to be swept along by his passion and vitality as he sets the scene for an encounter and then recounts every psychological twist and turn"),
#  Document(id='3e8a5f94-04d7-44bc-b8b9-7a1d65f97b87', metadata={'source': 'tagged_description.txt'}, page_content='9780753814413 Roddy Doyle¿s account of the Republic of Ireland¿s triumphant journey through Italia ¿90 is just one of the many first-class pieces in this anthology of original football writing. Contributors include: Roddy Doyle, Harry Pearson, Harry Ritchie, Ed Horton, Olly Wicken, D.J. Taylor, Huw Richards, Nick Hornby, Chris Pierson, Matt Nation, Graham Brack, Don Watson and Giles Smith. ¿A new kind of football writing developed ¿ passionate, disrespectful, self-mocking, yet steeped in personal bias. In book form, young writers such as Nick Hornby and Pete Davies became to the New Football Writing what Tom Wolfe and Hunter S. Thompson had been to the New Journalism¿ Terence Blacker, Sunday Times'),
#  Document(id='a89fa3c6-683a-4714-9630-7bf0e4f30a28', metadata={'source': 'tagged_description.txt'}, page_content="9781416500339 Each volume in a collection of affordable, readable editions of some of the world's greatest works of literature features a chronology of the author's life and career, a concise introduction containing valuable background information, a timeline of significant events, an outline of key plot points and themes, detailed explanatory notes, critical analyses, discussion questions, and a list of recommended books and films."),
#  Document(id='39007c8f-25b6-4e3f-9234-019ceacdf1dd', metadata={'source': 'tagged_description.txt'}, page_content="9781416500391 Each volume in a collection of affordable, readable editions of some of the world's greatest works of literature features a chronology of the author's life and career, a concise introduction containing valuable background information, a timeline of significant events, an outline of key plot points and themes, detailed explanatory notes, critical analyses, discussion questions, and a list of recommended books and films."),
#  Document(id='b33a863f-a5ac-4f19-b8b0-85cb08cc116d', metadata={'source': 'tagged_description.txt'}, page_content="9780606349154 One of the 20th century's enduring works, Marquez's masterpiece is the ultimate achievement in a Nobel Prize- winning career. Alternately reverential and comical, this novel weaves the political, personal, and spiritual to bring a new consciousness to storytelling.\n9780609610572 An updated edition of the best-selling reference features a new introduction on how to execute necessary business processes in light of today's challenging economic and financial environment. Cowritten by the author of What the CEO Wants You to Know.\n9780613013376 When their father is captured during the war, three children come to London to live with their grandmother and join all the cousins of their talented theatrical family in a school for stage training."),
#  Document(id='969b7dc2-192a-4dcf-a5c6-0a837b25d6b4', metadata={'source': 'tagged_description.txt'}, page_content="9780143037576 The perfect books for the true book lover, Penguin's Great Ideas series features twelve more groundbreaking works by some of history's most prodigious thinkers. Each volume is beautifully packaged with a unique type-driven design that highlights the bookmaker's art. Offering great literature in great packages at great prices, this series is ideal for those readers who want to explore and savor the Great Ideas that have shaped our world. Inspired by the trial of a bureaucrat who helped cause the Holocaust, this radical work on the banality of evil stunned the world with its exploration of a regime's moral blindness and one man's insistence that he be absolved all guilt because he was 'only following orders'."),
#  Document(id='c81080e4-0161-437b-a43f-a0d03a20d8b7', metadata={'source': 'tagged_description.txt'}, page_content="9780061139635 In this intense and brilliant book Bowles focuses on Morocco, condensing expreience, emotion, and the whole history of a people into a series of short, insightful vignettes. He distills for us the very essence of Moroccan culture. With extraordinary immediacy, he takes the reader on a journey through the Moroccan centuries, pausing at points along the way to create resonant images of the country, it's landscapes, and the beliefs and characteristics of its inhabitants."),
#  Document(id='0a0d883e-a3e4-4758-a840-59f8b27e27b2', metadata={'source': 'tagged_description.txt'}, page_content="9780786816156 A BookSense 76 pick, and best-seller from coast to coast-Summerland is part fantasy, part adventure, part baseball, but most of all it's the story of a young boy, Ethan Feld-a lousy, but lovable little-leaguer who finds himself playing in the most important baseball game ever. Not only the game, but the fate of the world rests on his shoulders."),
#  Document(id='815c434a-c1cc-4c64-a108-6cb1006755d4', metadata={'source': 'tagged_description.txt'}, page_content='9783856305581 Miguel Serrano, a Chilean diplomat and writer who has travelled widely in India studying Yoga, had a close friendship with Jung and Hermann Hesse at the end of their lives. This book is the outcome of his meetings and correspondence with them. Many letters are reproduced, including a document of great importance written to the author by Jung shortly before his death, explaining his ideas about the nature of the world and of his work.')]

# %%
books[books["isbn13"] == int(docs[0].page_content.split()[0].strip())]
# Out:
#              isbn13      isbn10        title      authors  \
# 4700  9781573226882  1573226882  Fever Pitch  Nick Hornby
#
#                      categories  \
# 4700  Biography & Autobiography
#
#                                               thumbnail  \
# 4700  http://books.google.com/books/content?id=v5TO8...
#
#                                             description  published_year  \
# 4700  An autobiographical memoir by a humorous Briti...          1998.0
#
#       average_rating  num_pages  ratings_count title_and_subtitle  \
# 4700            3.73      247.0        27781.0        Fever Pitch
#
#                                      tagged_description
# 4700  9781573226882 An autobiographical memoir by a ...

# %%
def semantic_recommendation_list(query:str,top_k:int = 10) -> pd.DataFrame:
    recs = db.similarity_search(query, k = 10)

    book_list = []
    for i in range(0, len(recs)):
        book_list +=[int(recs[i].page_content.strip('"').split()[0])]

    return books[books["isbn13"].isin(book_list)]

# %%
semantic_recommendation_list("a books to teach love")
# Out:
#              isbn13      isbn10                                    title  \
# 156   9780060574215  0060574216  Men Are from Mars, Women Are from Venus
# 211   9780060753634  0060753633                      Mating in Captivity
# 370   9780061129735  0061129739                        The Art of Loving
# 424   9780064410724  0064410722                       Four Stupid Cupids
# 2278  9780446606813  0446606812                      Message in a Bottle
# 2825  9780571206926  0571206921                          Laughable Loves
# 3428  9780743495929  0743495926                Getting the Love You Want
# 3534  9780755304851  0755304853                          Falling for You
# 3811  9780802130365  0802130364                      The Malady of Death
# 5102  9781890159191  1890159190                      The Mistress Manual
#
#                                         authors              categories  \
# 156                                   John Gray  Family & Relationships
# 211                                Esther Perel              Psychology
# 370                                 Erich Fromm               Self-Help
# 424                             Gregory Maguire        Juvenile Fiction
# 2278                            Nicholas Sparks                 Fiction
# 2825                              Milan Kundera          Czech Republic
# 3428                           Harville Hendrix                    Love
# 3534                               Jill Mansell                 Fiction
# 3811                           Marguerite Duras                 Fiction
# 5102  Mistress Lorelei;Lorelei Powers, Mistress  Family & Relationships
#
#                                               thumbnail  \
# 156   http://books.google.com/books/content?id=MUw_d...
# 211   http://books.google.com/books/content?id=-HIhM...
# 370   http://books.google.com/books/content?id=TRMED...
# 424   http://books.google.com/books/content?id=471OU...
# 2278  http://books.google.com/books/content?id=0uvZR...
# 2825  http://books.google.com/books/content?id=ZpupP...
# 3428  http://books.google.com/books/content?id=Vc56P...
# 3534  http://books.google.com/books/content?id=K3zCG...
# 3811  http://books.google.com/books/content?id=ZDHyw...
# 5102  http://books.google.com/books/content?id=DjOZv...
#
#                                             description  published_year  \
# 156   Rediscover the most famous relationship book e...          2004.0
# 211   A guide for loving couples who are looking to ...          2006.0
# 370   The fiftieth Anniversary Edition of the ground...          2006.0
# 424   The students' scheme to find a love match for ...          2001.0
# 2278  In this New York Times bestseller, a single mo...          1999.0
# 2825  Laughable loves is a collection of stories tha...          1999.0
# 3428  Originally published in 1988, GETTING THE LOVE...          2005.0
# 3534  Love is always just around the corner in a Jil...          2004.0
# 3811  A man hires a woman to spend several weeks wit...          1988.0
# 5102  Originally published in 1994 in a simple pink ...          2000.0
#
#       average_rating  num_pages  ratings_count  \
# 156             3.54      368.0       126108.0
# 211             4.13      272.0         7699.0
# 370             4.03      192.0        35605.0
# 424             3.52      224.0          110.0
# 2278            3.96      370.0         2714.0
# 2825            3.87      287.0        14380.0
# 3428            4.07      336.0         5513.0
# 3534            3.79      448.0         4713.0
# 3811            3.86       60.0         1280.0
# 5102            3.76      220.0          323.0
#
#                                      title_and_subtitle  \
# 156   Men Are from Mars, Women Are from Venus: The C...
# 211   Mating in Captivity: Reconciling the Erotic an...
# 370                                   The Art of Loving
# 424                                  Four Stupid Cupids
# 2278                                Message in a Bottle
# 2825                                    Laughable Loves
# 3428     Getting the Love You Want: A Guide for Couples
# 3534                                    Falling for You
# 3811                                The Malady of Death
# 5102  The Mistress Manual: A Good Girl's Guide to Fe...
#
#                                      tagged_description
# 156   9780060574215 Rediscover the most famous relat...
# 211   9780060753634 A guide for loving couples who a...
# 370   9780061129735 The fiftieth Anniversary Edition...
# 424   9780064410724 The students' scheme to find a l...
# 2278  9780446606813 In this New York Times bestselle...
# 2825  9780571206926 Laughable loves is a collection ...
# 3428  9780743495929 Originally published in 1988, GE...
# 3534  9780755304851 Love is always just around the c...
# 3811  9780802130365 A man hires a woman to spend sev...
# 5102  9781890159191 Originally published in 1994 in ...
